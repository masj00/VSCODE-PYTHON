# %% [markdown]
# Union = python | ai
# så for vi alle
#
# intersection = python & ai
# så for vi dem der kun har begge
#
# Difference = python - ai
# så for vi dem der kun er i python (man kan også lave den omvendt)
#
# Symmetrisk diff = python ^ ai
# så for vi dem som kun har python og kun ai

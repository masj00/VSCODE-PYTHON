# %% [markdown]
# Decorators

# %%
def add():
    return None

# %%
print(type(add()))
# Out:
# <class 'NoneType'>

# %% [markdown]
# Ny

# %%
def foo():
    def bar():
        def zoo():
            return "Hello from zoo!"
        return zoo()
    return bar()

# %%
foo()
# Out:
# <function __main__.foo.<locals>.bar()>

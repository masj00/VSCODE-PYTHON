# %% [markdown]
# # Kode fra undervisningen (Intro)

# %% [markdown]
# ## Hello world

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ## Variabler

# %%
a = 'Hello World'
a = 12
a = False
a = 13.5
l = [1, 2, 3]

type(l)
# Out:
# list

# %% [markdown]
# Python er dynamisk og man kan ændre ens variable

# %% [markdown]
# ## Datatyper
# * int
# * String
# * float
# * bool
# * list
# * tuple
# * set
# * dictionary

# %% [markdown]
# ## Indbyggede funktioner
# https://docs.python.org/3/library/functions.html

# %%
x = input('Hvad ville du gerne sige?')

# %%
x
# Out:
# 'hej'

# %% [markdown]
# ## Hvad er ... ?
# * help
# * dir
# * ChatGpt
# * Google

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %% [markdown]
# ## Q: Kan jeg sammensætte en tekst streg og en int?

# %%
'Hello' + str(12)
# Out:
# 'Hello12'

# %% [markdown]
# ## Funktioner, indentering, betingelser, compilering

# %%
def message(name):

    if name == 'Claus':
        return f'Hej {name}'
    else:
        return 'NO NO NO'
    
message('Anne')
# Out:
# 'NO NO NO'

# %%
message('Claus')
# Out:
# 'Hej Claus'

# %% [markdown]
# ## String

# %%
a = 'Hello'

# %% [markdown]
# ## String metoder

# %%
a.upper()
# Out:
# 'HELLO'

# %% [markdown]
# ## Indexerede

# %%
a[0]
# Out:
# 'H'

# %% [markdown]
# få det første indextal ud a[0]
# sidste tal med [-1]

# %% [markdown]
# ## String formatering
# * \+
# * f-string

# %%
a =  f'hello + {str(12)}'
a
# Out:
# 'hello + 12'

# %% [markdown]
# ## Slicing

# %%
a[1:4]
# Out:
# 'ell'
